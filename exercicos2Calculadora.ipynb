# %% [markdown]
# <a href="https://colab.research.google.com/github/Marie935/GIT.EXERCICIOS/blob/main/exercicos2Calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculadora(num1, num2, operacao):
    if operacao == 1:
        return num1 + num2
    elif operacao == 2:
        return num1 - num2
    elif operacao == 3:
        return num1 * num2
    elif operacao == 4:
        if num2 != 0:
            return num1 / num2
        else:
            return "Erro: Divisão por zero não permitida"
    else:
        return "Essa opção não existe"

def menu():
    print("Selecione a operação:")
    print("1 - Soma")
    print("2 - Subtração")
    print("3 - Multiplicação")
    print("4 - Divisão")
    print("5 - Sair")

while True:
    menu()
    operacao = int(input("Digite o número da operação desejada: "))

    if operacao == 5:
        print("Encerrando o sistema...")
        break

    if operacao in [1, 2, 3, 4]:
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))
        resultado = calculadora(num1, num2, operacao)
        print(f"O resultado da operação é: {resultado}")
    else:
        print("Essa opção não existe. Tente novamente.")

    print()  # Linha em branco para melhor visualização
# Out:
# Selecione a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
# Digite o número da operação desejada: 8
# Essa opção não existe. Tente novamente.
#
# Selecione a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
# Digite o número da operação desejada: 0
# Essa opção não existe. Tente novamente.
#
# Selecione a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
# Digite o número da operação desejada: 0
# Essa opção não existe. Tente novamente.
#
# Selecione a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
# Digite o número da operação desejada: 368
# Essa opção não existe. Tente novamente.
#
# Selecione a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
# Digite o número da operação desejada: 0
# Essa opção não existe. Tente novamente.
#
# Selecione a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# ...
